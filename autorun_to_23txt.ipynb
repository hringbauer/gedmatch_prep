# %% [markdown]
# # Prepare 23andme SNPs imputed HDF5s from 1000G imputed VCFs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import socket as socket
import os as os
import sys as sys
import h5py
import matplotlib.cm as cm
import itertools as it
import multiprocessing as mp
socket_name = socket.gethostname()
print(socket_name)

if socket_name.startswith("bionc"):
    print("Leipzig Cluster detected!")
    path = "/mnt/archgen/users/hringbauer/git/gedmatch_prep/python3/"
    #sys.path.append("/mnt/archgen/users/hringbauer/data/malta/") 
    
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")
    
os.chdir(path)  # Set the right Path (in line with Atom default)
print(os.getcwd())
print(f"CPU Count: {mp.cpu_count()}")

from prep_23txt import prep_h5_autorun_23, generate_23_from_h5
# Out:
# bionc21
# Leipzig Cluster detected!
# /mnt/archgen/users/hringbauer/git/gedmatch_prep/python3
# CPU Count: 40

# %% [markdown]
# # 1)  Prepare h5 (on 23andme v4&5 SNPs), and then 23andme txt

# %%
# %%time
iid = "CHC002"
prep_h5_autorun_23(iid=iid) # Generate h5

### Convert to 23andme
dft = generate_23_from_h5(chs =range(1,23), output=False, maxgp=0,
        h5_path = f"/mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/{iid}/",
        path_23tsv='/mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme/snps45.tsv',
        savepath =f"/mnt/archgen/users/hringbauer/git/gedmatch_prep/output/txt23/{iid}.snps45.txt")
# Out:
# Running Chromosome 1...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch1.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch1.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 79239 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch1.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch1.h5
#
# Running Chromosome 2...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch2.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch2.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 82595 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch2.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch2.h5
#
# Running Chromosome 3...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch3.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch3.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 69195 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch3.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch3.h5
#
# Running Chromosome 4...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch4.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch4.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 63710 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch4.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch4.h5
#
# Running Chromosome 5...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch5.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch5.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 60823 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch5.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch5.h5
#
# Running Chromosome 6...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch6.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch6.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 70260 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch6.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch6.h5
#
# Running Chromosome 7...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch7.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch7.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 55823 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch7.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch7.h5
#
# Running Chromosome 8...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch8.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch8.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 53707 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch8.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch8.h5
#
# Running Chromosome 9...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch9.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch9.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 45137 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch9.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch9.h5
#
# Running Chromosome 10...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch10.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch10.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 51563 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch10.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch10.h5
#
# Running Chromosome 11...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch11.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch11.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 49149 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch11.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch11.h5
#
# Running Chromosome 12...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch12.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch12.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 48318 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch12.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch12.h5
#
# Running Chromosome 13...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch13.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch13.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 36737 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch13.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch13.h5
#
# Running Chromosome 14...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch14.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch14.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 32610 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch14.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch14.h5
#
# Running Chromosome 15...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch15.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch15.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 30507 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch15.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch15.h5
#
# Running Chromosome 16...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch16.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch16.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 32045 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch16.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch16.h5
#
# Running Chromosome 17...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch17.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch17.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 28401 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch17.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch17.h5
#
# Running Chromosome 18...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch18.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch18.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 29729 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch18.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch18.h5
#
# Running Chromosome 19...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch19.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch19.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 20504 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch19.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch19.h5
#
# Running Chromosome 20...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch20.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch20.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 24927 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch20.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch20.h5
#
# Running Chromosome 21...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch21.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch21.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 14473 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch21.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch21.h5
#
# Running Chromosome 22...
# Print downsampling to 1240K...
# Running bash command:
# bcftools view -Oz -o /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/vcfs.23imp45/CHC002/ch22.vcf.gz -T /mnt/archgen/users/hringbauer/git/gedmatch_prep/data/23andme45/bcftools_ch22.csv -M2 -v snps /mnt/archgen/Autorun_eager/eager_outputs/TF/CHC/CHC002/GTL_output/CHC002_imputed.vcf.gz
# Finished BCF tools filtering to target markers.
# Converting to HDF5...
# Finished conversion to hdf5!
# Merging in LD Map..
# Calculating in sample allele frequencies and saving at hdf5 column AF_SAMPLE
# Adding Allele Frequencies to HDF5...
# Loaded 14595 variants.
# Finshed merged in allele frequencies into /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch22.h5
# Transformation complete! Find new hdf5 file at: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/h5.23imp45/CHC002/ch22.h5
#
# Successfully saved 23andmefile to: /mnt/archgen/users/hringbauer/git/gedmatch_prep/output/txt23/CHC002.snps45.txt
# CPU times: user 33 s, sys: 3.6 s, total: 36.6 s
# Wall time: 15min 44s

# %% [markdown]
# # Area 51

# %%
len(dft)
# Out:
# 994884

# %%
df_ch = dft[dft["chr"]==str(3)]

# %%
np.mean(df_ch["gp"]>=0.99)
# Out:
# 0.8366863563495617
